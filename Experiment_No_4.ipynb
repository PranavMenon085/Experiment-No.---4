# %% [markdown]
# Experiment No.4\
# Name : Pranav Menon\
# PRN No. : 25070123085\
# Batch : ENTC - B1\
# Aim of the experiment : Study of Set in Python

# %%
# Introduction to Set
thisset = {"apple", "banana", "cherry"}
print(thisset)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
# Duplication of Sets are Not Allowed
thisset = {"apple", "banana", "cherry", "apple"}
print(thisset)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
# Logical Command Application in Set
thisset = {"apple", "banana", "cherry",True,1,2}
print((thisset))
# Out:
# {True, 2, 'cherry', 'apple', 'banana'}

# %%
# To check for the membership in a Set
thisset = {"apple", "banana", "cherry"}
print("banana" in thisset)
print("Grapes" in thisset)
# Out:
# True
# False

# %%
# Addition of an element in a set
thisset = {"apple", "banana", "cherry"}
thisset.add("orange")
print(thisset)
# Out:
# {'orange', 'banana', 'cherry', 'apple'}

# %%
# Removal of an element from a set
thisset = {"apple", "banana", "cherry"}
thisset.remove("banana")
print(thisset)
# Out:
# {'cherry', 'apple'}

# %%
# Operations on a set
A = {1,2,3,4}
B = {3,4,5,6}
print("Union : ", A | B)
print("Intersection : ", A & B)
print("Difference 1 : ", A - B)
print("Difference 2 : " , B-A)
print("Symmetric Difference : ", A ^ B)
# Out:
# Union :  {1, 2, 3, 4, 5, 6}
# Intersection :  {3, 4}
# Difference 1 :  {1, 2}
# Difference 2 :  {5, 6}
# Symmetric Difference :  {1, 2, 5, 6}

# %%
# Introduction to FrozenSet
x = frozenset(["apple","banana","cherry"])
print(x)
print(type(x))
# Out:
# frozenset({'banana', 'cherry', 'apple'})
# <class 'frozenset'>

# %%
# Practice Problems on Set
student_Name = ["Pranav" , "Praharsh" , "Harsh" , "Aditya","Dhruv","Pranav","Aditya","Dhruv"]
Student_Name = set(student_Name)
print("Unique Participants : " ,Student_Name)
# Out:
# Unique Participants :  {'Pranav', 'Aditya', 'Dhruv', 'Praharsh', 'Harsh'}

# %%
# Practice Problems on Set
Student1 = {"Maths","Physics","Biology","Python"}
Student2 = {"Maths","Chemistry","Biology","Python"}
Student3 = {"Maths","Physics","Chemistry","Python"}
print("The Subjects Common to all the three Student is : " , Student1 & Student2 & Student3)
print("The Subjects Common to all the three Student is : " , Student1.intersection(Student2,Student3))
# Out:
# The Subjects Common to all the three Student is :  {'Maths', 'Python'}
# The Subjects Common to all the three Student is :  {'Maths', 'Python'}

# %%
# Practice Problems on Set
Cricket_Club = {"Pranav","Praharsh","Aditya","Amar","Rahul"}
FootBall_Club = {"Aditya","Pranav","Rahul","Shyam","Raju"}
Common = Cricket_Club & FootBall_Club
Not_Common = Cricket_Club ^ FootBall_Club
Cricket = Cricket_Club - FootBall_Club
Football = FootBall_Club - Cricket_Club
print("The Members Common to both the clubs are : " , Common)
print("The Members which are unique to the clubs are : " , Not_Common)
print("The Members which are unique to the Cricket Club are : " , Cricket)
print("The Members which are unique to the Football Club are : " , Football)
# Out:
# The Members Common to both the clubs are :  {'Rahul', 'Pranav', 'Aditya'}
# The Members which are unique to the clubs are :  {'Shyam', 'Raju', 'Amar', 'Praharsh'}
# The Members which are unique to the Cricket Club are :  {'Amar', 'Praharsh'}
# The Members which are unique to the Football Club are :  {'Shyam', 'Raju'}

# %%
# Practice Problems on Set
all_students = {"Pranav","Praharsh","Aditya","Amar","Rahul"}
present_student = {"Aditya","Pranav","Rahul","Shyam","Raju"}
absent_student = all_students - present_student
print("The Students who are absent are :", absent_student)
# Out:
# The Students who are absent are : {'Amar', 'Praharsh'}

# %%
# Pracice Problems on Set
current_courses = {"Physics","Chemistry","Biology","Math","Python","Digital Circuits and Logic Design"}
current_courses.discard("Chemistry")
print("Updated Courses : " , current_courses)
current_courses.remove("Math")
print("Updated Courses : " , current_courses)
# Out:
# Updated Courses :  {'Physics', 'Math', 'Python', 'Biology', 'Digital Circuits and Logic Design'}
# Updated Courses :  {'Physics', 'Python', 'Biology', 'Digital Circuits and Logic Design'}
